# %%
(isinstance(23,int) and 21)
# Out:
# 21

# %%
import os

os.listdir()
for i in range(11,26):
    with open(f'programming_assignment{i}.ipynb','w') as f:
        f.close()

# %%
a=[1,2,3,5,5,4,3,2,'1']

# %%
a
# Out:
# [1, 2, 3, 5, 5, 4, 3, 2, '1']

# %%
for i in range(len(a)):
    a[i]=int(a[i])

# %%
print(a.sort())
# Out:
# None

# %%
from itertools import combinations_with_replacement, combinations

# %%
A,B = input().split()



# for i in range (1,int(B)+1):
#     AxB = list(combinations_with_replacement(sorted(A), i))
#     for p in AxB:
#         print("".join(p))


A,B = input().split()

AxB = list(combinations_with_replacement(sorted(A), int(B)))
for p in AxB:
    print("".join(p))
# Out:
# aa
# ac
# ah
# ak
# cc
# ch
# ck
# hh
# hk
# kk

# %%
from itertools import groupby

A= input()

# %%
grouped = groupby(A)

# %%
result = [(len(list(group)), int(key)) for key, group in grouped]
# Print the result
for item in result:
    print('({0}, {1})'.format(item[0], item[1]), end=' ')
# Out:
# (1, 1) (1, 2) (1, 3) (1, 2) (1, 1) (1, 2) (1, 3) (1, 4) (1, 2) (1, 3) (1, 4) (1, 2) (1, 1) (1, 3)

# %%
print(result)
# Out:
# ()

# %%
for key,group in grouped:
    print(tuple(int(key), len(list(group))))

# %%
A= int(input())
B= list(input().split())
C= int(input())

# %%
combinations(B, int(A))

# %%
from itertools import combinations
N ,string , K = int(input()), input().split(), int(input())
count=0
for i in combinations(string,K):
    count+=1
print(count)
counta=0
for i in combinations(string,K):
    if string[K-1] in i:
        print(string[K-1],i)
        counta+=1
print(counta)
print(counta/count)
# Out:
# 6
# a ('a', 'a')
# a ('a', 'c')
# a ('a', 'd')
# a ('a', 'c')
# a ('a', 'd')
# 5
# 0.8333333333333334

# %%
from itertools import combinations

A= int(input())
B= list(input().split())
C= int(input())

count = 0
for i in combinations(B,C):
    count+=1
counta = 0    
for i in combinations(B,C):
    if B[C-1]in i:
        counta+=1
print(counta/count)

# %%
n = int(input())  # read the length of the list
letters = input().split()  # read the list of letters
k = int(input())  # read the number of indices to be selected

# %%
from itertools import combinations

# %%
letters
count = 0 
lenght = 0
for i in combinations(letters,k):
    lenght+=1
    if 'a' in i:
        count+=1
print(count/lenght)

# %%
count
# Out:
# 5

# %%
lenght
# Out:
# 6

# %%
count/lenght
# Out:
# 0.8333333333333334

# %%
from collections import Counter

num_shoes = int(input())
shoe_sizes = Counter(map(int, input().split()))
num_customers = int(input())
total_earnings = 0

# %%
for i in range(num_customers):
    desired_size, price = map(int, input().split())
    if shoe_sizes[desired_size] > 0:
        total_earnings += price
        shoe_sizes[desired_size] -= 1

# Print the total earnings
print(total_earnings)

# %%
for i in range(num_customers):
    if shoe_sizes[desired_size] > 0:
        total_earnings += price
        print(shoe_sizes[desired_size])
        shoe_sizes[desired_size] -= 1

# %%
desired_size
# Out:
# 10

# %%
test = {161, 182, 161, 154, 176, 170, 167, 171, 170, 174  }

# %%
# !pip install numpy
# Out:
# ...
#   Using cached numpy-1.24.2-cp311-cp311-win_amd64.whl (14.8 MB)
# ...

# %%
import numpy as np

# %%
from statistics import mean

# %%
mean(test)
# Out:
# 169.375

# %%
from statistics import mean

def average(array):
    return mean(array)

if __name__ == '__main__':
    n = int(input())
    arr = list(map(int, input().split()))
    result = average(arr)
    print("{:.3f}".format(result))
# Out:
# 168.600

# %%
mean(test)
# Out:
# 169.375

# %%
def average(array):
    return mean(set(array))

if __name__ == '__main__':
    n = int(input())
    arr = list(map(int, input().split()))
    result = average(arr)
    print(result)
# Out:
# 169.375

# %%
m = int(input())
set_a = set(map(int, input().split()))
n = int(input())
set_b = set(map(int, input().split()))

set_a.symmetric_difference(set_b)
# Out:
# {5, 9, 11, 12}

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the time_delta function below.
def time_delta(t1, t2):
    t3 = t2-t1
    return t3

if __name__ == '__main__':
    fptr = open(os.environ['PATH'], 'w')

    t = int(input())

    for t_itr in range(t):
        t1 = input()

        t2 = input()

        delta = time_delta(t1, t2)

        fptr.write(delta + '\n')

    fptr.close()

# %%
class Employee:
    def __init__(self,firstname, lastname, company) -> None:
        self.firstname = firstname
        self.lastname  = lastname
        self.company = company

    @property
    def email(self):
        return (self.firstname + self.lastname + '@' + self.company + '.com')
    
    @email.setter
    def email(self, email):
        self.email = email
    
    
    




emp1 = Employee('david', 'louise', 'testingcomp')

emp1.email  = "tthisiatest@rmail.com"

# %%
emp1.email  = 'tthisiatest@rmail.com'
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import math

AB = int(input())
BC = int(input())


angle = math.atan2(AB,BC)

degree = round(math.degrees(angle))

print(str(degree) + chr(176))
# Out:
# 45°

# %%
# define a list of filenames
filenames = 'assignment'

# loop through the filenames list and create a file with each name
for i in range(11,12):
    with open(filenames+str(i)+'.ipynb', 'w') as file:
        pass

# %%
# !pip install pytz
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import datetime, pytz



t = datetime.datetime(2023, 4, 16, 7,23,23,10000, tzinfo= pytz.UTC)

# %%
print(t)
# Out:
# 2023-04-16 07:23:23.010000+00:00

# %%
for i in pytz.all_timezones:
    print(i)
# Out:
# Africa/Abidjan
# Africa/Accra
# Africa/Addis_Ababa
# Africa/Algiers
# Africa/Asmara
# Africa/Asmera
# Africa/Bamako
# Africa/Bangui
# Africa/Banjul
# Africa/Bissau
# Africa/Blantyre
# Africa/Brazzaville
# Africa/Bujumbura
# Africa/Cairo
# Africa/Casablanca
# Africa/Ceuta
# Africa/Conakry
# Africa/Dakar
# Africa/Dar_es_Salaam
# Africa/Djibouti
# Africa/Douala
# Africa/El_Aaiun
# Africa/Freetown
# Africa/Gaborone
# Africa/Harare
# Africa/Johannesburg
# Africa/Juba
# Africa/Kampala
# Africa/Khartoum
# Africa/Kigali
# Africa/Kinshasa
# Africa/Lagos
# Africa/Libreville
# Africa/Lome
# Africa/Luanda
# Africa/Lubumbashi
# Africa/Lusaka
# Africa/Malabo
# Africa/Maputo
# Africa/Maseru
# Africa/Mbabane
# Africa/Mogadishu
# Africa/Monrovia
# Africa/Nairobi
# Africa/Ndjamena
# Africa/Niamey
# Africa/Nouakchott
# Africa/Ouagadougou
# Africa/Porto-Novo
# Africa/Sao_Tome
# Africa/Timbuktu
# Africa/Tripoli
# Africa/Tunis
# Africa/Windhoek
# America/Adak
# America/Anchorage
# America/Anguilla
# ...

# %%
# Africa/Accra
for i in pytz.all_timezones:
    print(t.astimezone(pytz.timezone(i)))
# Out:
# 2023-04-16 07:23:23.010000+00:00
# 2023-04-16 07:23:23.010000+00:00
# 2023-04-16 10:23:23.010000+03:00
# 2023-04-16 08:23:23.010000+01:00
# 2023-04-16 10:23:23.010000+03:00
# 2023-04-16 10:23:23.010000+03:00
# 2023-04-16 07:23:23.010000+00:00
# 2023-04-16 08:23:23.010000+01:00
# 2023-04-16 07:23:23.010000+00:00
# 2023-04-16 07:23:23.010000+00:00
# 2023-04-16 09:23:23.010000+02:00
# 2023-04-16 08:23:23.010000+01:00
# 2023-04-16 09:23:23.010000+02:00
# 2023-04-16 09:23:23.010000+02:00
# 2023-04-16 07:23:23.010000+00:00
# 2023-04-16 09:23:23.010000+02:00
# 2023-04-16 07:23:23.010000+00:00
# 2023-04-16 07:23:23.010000+00:00
# 2023-04-16 10:23:23.010000+03:00
# 2023-04-16 10:23:23.010000+03:00
# 2023-04-16 08:23:23.010000+01:00
# 2023-04-16 07:23:23.010000+00:00
# 2023-04-16 07:23:23.010000+00:00
# 2023-04-16 09:23:23.010000+02:00
# 2023-04-16 09:23:23.010000+02:00
# 2023-04-16 09:23:23.010000+02:00
# 2023-04-16 09:23:23.010000+02:00
# 2023-04-16 10:23:23.010000+03:00
# ...

# %%
# !pip install redis
# Out:
# ...
#      ---------------------------------------- 0.0/238.9 kB ? eta -:--:--
#      ---------------------- --------------- 143.4/238.9 kB 4.3 MB/s eta 0:00:01
#      -------------------------------------- 238.9/238.9 kB 2.4 MB/s eta 0:00:00
# ...
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import redis

# %%
r = redis.Redis()

# %%
capital_dict = {'Albania':'Tirana', 'Algeria':'Algiers','Andorra':'Andorra la Vella','Angola':'Luanda'}

# %%
r.mset(capital_dict)
# Out:
# True

# %%
r.get('Albania')
# Out:
# b'Tirana'
