# %%
# 1. Add the current date to the text file today.txt as a string.
from datetime import date, datetime

with open('today.txt','w') as f:
    f.write(str(date.today()))
    f.close
# 2. Read the text file today.txt into the string today_string

with open('today.txt','r') as f:
    today_string = f.readline()
# 3. Parse the date from today_string.
paresed_date = datetime.strptime(today_string,'%Y-%m-%d')
# 4. List the files in your current directory
import os
os.listdir()
# 5. Create a list of all of the files in your parent directory (minimum five files should be available).
parent_file_list = os.listdir('..')

# 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

import multiprocessing
import random
import time
from datetime import datetime

def process_func():
    sleep_time = random.randint(1,5)
    time.sleep(sleep_time)
    print(datetime.now())
    print(f"Process finished at {now}, slept for {sleep_time} seconds.")

processes= []
for i in range(3):
    p = multiprocessing.Process(target= process_func)
    p.start()
    processes.append(p)

for p in processes:
    p.join()



# 7. Create a date object of your day of birth.
b_day = datetime.date(1994,12,14)

# 8. What day of the week was your day of birth?

# 9. When will you be (or when were you) 10,000 days old?

# %%
import # 1. Add the current date to the text file today.txt as a string.
from datetime import date, datetime

with open('today.txt','w') as f:
    f.write(str(date.today()))
    f.close
# 2. Read the text file today.txt into the string today_string

with open('today.txt','r') as f:
    today_string = f.readline()
# 3. Parse the date from today_string.
paresed_date = datetime.strptime(today_string,'%Y-%m-%d')
# 4. List the files in your current directory
import os
os.listdir()
# 5. Create a list of all of the files in your parent directory (minimum five files should be available).
parent_file_list = os.listdir('..')

# 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

import multiprocessing
import random
import time
from datetime import datetime

def process_func():
    sleep_time = random.randint(1,5)
    time.sleep(sleep_time)
    print(datetime.now())
    print(f"Process finished at {now}, slept for {sleep_time} seconds.")

processes= []
for i in range(3):
    p = multiprocessing.Process(target= process_func)
    p.start()
    processes.append(p)

for p in processes:
    p.join()



# 7. Create a date object of your day of birth.
b_day = datetime.date(1994,12,14)

# 8. What day of the week was your day of birth?

# 9. When will you be (or when were you) 10,000 days old?

# %%
# 1. Add the current date to the text file today.txt as a string.
from datetime import date, datetime

with open('today.txt','w') as f:
    f.write(str(date.today()))
    f.close
# 2. Read the text file today.txt into the string today_string

with open('today.txt','r') as f:
    today_string = f.readline()
# 3. Parse the date from today_string.
paresed_date = datetime.strptime(today_string,'%Y-%m-%d')
# 4. List the files in your current directory
import os
os.listdir()
# 5. Create a list of all of the files in your parent directory (minimum five files should be available).
parent_file_list = os.listdir('..')

# 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

import multiprocessing
import random
import time
from datetime import datetime

def process_func():
    sleep_time = random.randint(1,5)
    time.sleep(sleep_time)
    print(datetime.now())
    print(f"Process finished at {now}, slept for {sleep_time} seconds.")

processes= []
for i in range(3):
    p = multiprocessing.Process(target= process_func)
    p.start()
    processes.append(p)

for p in processes:
    p.join()



# 7. Create a date object of your day of birth.
birthday = datetime.date(1994, 12, 14)

# 8. What day of the week was your day of birth?
birthday.strftime('%A')

# 9. When will you be (or when were you) 10,000 days old?
t_delta = datetime.timedelta(days=10000)
print(birthday + t_delta)
